# %% [markdown]
# # Company Specific Housing Data
#
# How to Plan Resourcing for Future Delivery

# %% [markdown]
# ![Buildings.jpg](attachment:Buildings.jpg)

# %% [markdown]
# # 1. Data
#
# The dataset that I used is owned by the company that I work at, and it has been cleansed of personal data. In this assignment I have also used other datasets such as Titanic when using NumPy as it has more numeric data. All datasets are located at https://github.com/AnnHayes23/UCDPA_AnnHayesFinal/tree/main/data

# %%
#importing packages 
import pandas as pd
import numpy as ny
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Importing Data
#
# I imported the csv file, Property Dataset Final, for my assignment. I also imported the 'Student Mental Health' dataset from Kaggle and the 'Tips' dataset from seaborn. To demonstrate using APIs to import data, I imported 'Movie Genres' from https://rapidapi.com/

# %%
import pandas as pd
property = pd.read_csv(r'../data/Property Dataset Final.csv')
property.head()
# Out:
#   PropertyID PropertyStreetCode PropertyTown PropertyCounty  \
# 0     U13210      Ard Na Greine     Milltown      Co. Kerry
# 1     U13211      Ard Na Greine     Milltown      Co. Kerry
# 2     U13217      Ard Na Greine     Milltown      Co. Kerry
# 3     U13223      Ard Na Greine     Milltown      Co. Kerry
# 4     U13224      Ard Na Greine     Milltown      Co. Kerry
#
#   PropertyCurrentStatus PropertyType PropertyAreaOffice  \
# 0              Occupied     Property      Gerard Deegan
# 1              Occupied     Property      Gerard Deegan
# 2              Occupied     Property      Gerard Deegan
# 3              Occupied     Property      Gerard Deegan
# 4              Occupied     Property      Gerard Deegan
#
#           PropertyOwningBody PropertyLocalAuthorityArea PropertySubType  \
# 0  Residential In Management              Kerry County    General Needs
# 1  Residential In Management              Kerry County    General Needs
# ...

# %%
property.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10931 entries, 0 to 10930
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PropertyID                  10931 non-null  object
#  1   PropertyStreetCode          10931 non-null  object
#  2   PropertyTown                10692 non-null  object
#  3   PropertyCounty              10791 non-null  object
#  4   PropertyCurrentStatus       10871 non-null  object
#  5   PropertyType                10788 non-null  object
#  6   PropertyAreaOffice          10931 non-null  object
#  7   PropertyOwningBody          10931 non-null  object
#  8   PropertyLocalAuthorityArea  10870 non-null  object
#  9   PropertySubType             10906 non-null  object
#  10  PropertyStyle               10890 non-null  object
#  11  YearOfConstruction          10931 non-null  int64
#  12  BedSpaces                   10931 non-null  int64
# ...

# %%
#Importing dataset from Kaggle 
Student_MH = pd.read_csv(r'../data/Student Mental Health.csv')
Student_MH.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 11 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Timestamp                                     101 non-null    object
#  1   Choose your gender                            101 non-null    object
#  2   Age                                           100 non-null    float64
#  3   What is your course?                          101 non-null    object
#  4   Your current year of Study                    101 non-null    object
#  5   What is your CGPA?                            101 non-null    object
#  6   Marital status                                101 non-null    object
#  7   Do you have Depression?                       101 non-null    object
#  8   Do you have Anxiety?                          101 non-null    object
# ...

# %%
#Importing dataset from seaborn
import seaborn as sns
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
#importing data using APIs once I had subscribed to get a token
import requests
url = "https://unogsng.p.rapidapi.com/genres"

headers = {
    "X-RapidAPI-Key": "2f8253dc65mshf5db400c3152ac6p14007djsn78987098a841",
    "X-RapidAPI-Host": "unogsng.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {
#     "12739": "20th Century Period Pieces",
#     "77213": "Absurd Comedies",
#     "51063": "Academy Award-Winning Films",
#     "1365": "Acci\u00f3n y aventuras",
#     "2125": "Acci\u00f3n y aventuras militares",
#     "801362": "Action",
#     "10673": "Action & Adventure Programmes",
#     "2653": "Action Anime",
#     "43040": "Action Comedies",
#     "1568": "Action Sci-Fi & Fantasy",
#     "43048": "Action Thrillers",
#     "788212": "Actionkrimis",
#     "11881": "Adult Animation",
#     "7442": "Adventures",
#     "3761": "African Films",
#     "4906": "African-American Comedies",
#     "10778": "African-American Stand-up Comedy",
#     "3327": "Alien Sci-Fi",
#     "12123": "Ambientadas en otra \u00e9poca",
#     "72404": "American Programmes",
#     "5507": "Animal Tales",
#     "786708": "Animated Movies",
#     "4698": "Animation",
#     "7424": "Anime",
#     "1819777": "Anime based on a Video Game",
#     "1819776": "Anime based on Books",
# ...

# %%
#checking what type of data this is 
genres = response.text
type(genres)
# Out:
# str

# %%
import json as json
myfile = json.loads(response.text)

# %%
#converting genres to a DataFrame
movie_genres = pd.DataFrame(myfile.items(), columns = ["ID", "Genre"])
movie_genres.info
# Out:
# <bound method DataFrame.info of           ID                         Genre
# 0      12739    20th Century Period Pieces
# 1      77213               Absurd Comedies
# 2      51063   Academy Award-Winning Films
# 3       1365            Acción y aventuras
# 4       2125  Acción y aventuras militares
# ..       ...                           ...
# 659     7700                      Westerns
# 660     2856                   World Music
# 661    70023                    WWII Films
# 662  1502288                   Youth Drama
# 663    75405           Zombie Horror Films
#
# [664 rows x 2 columns]>

# %% [markdown]
# # 3. Preparation of Data
#
# Create a pandas DataFrame and demonstrate sorting, indexing, grouping, dropping duplicates, replacing missing values and merging DataFrames. This section inlcudes examples of using NumPy on Titanic dataset.

# %%
#Create pandas DataFrame
data = {'Names': ['Julian', 'Dick', 'Anne','George', 'Timmy']}
df = pd.DataFrame(data)
df
# Out:
#     Names
# 0  Julian
# 1    Dick
# 2    Anne
# 3  George
# 4   Timmy

# %%
#Create a DataFrame from my own Data
df = pd.DataFrame(property)
df.tail()
# Out:
#       PropertyID PropertyStreetCode PropertyTown PropertyCounty  \
# 10926     U14165     Letteragh Road      Galway      Co. Galway
# 10927     U14166     Letteragh Road      Galway      Co. Galway
# 10928     U14130          San Guida   Clondalkin      Dublin 22
# 10929     U14135          San Guida   Clondalkin      Dublin 22
# 10930     U14163     Letteragh Road      Galway      Co. Galway
#
#       PropertyCurrentStatus PropertyType PropertyAreaOffice  \
# 10926  Pre-acquisition Void     Property        Aimee McGee
# 10927  Pre-acquisition Void     Property        Aimee McGee
# 10928  Pre-acquisition Void     Property        Brian Lambe
# 10929  Pre-acquisition Void     Property        Brian Lambe
# 10930  Pre-acquisition Void     Property        Aimee McGee
#
#                  PropertyOwningBody PropertyLocalAuthorityArea  \
# 10926  In Development - pre closing               Galway City
# 10927  In Development - pre closing               Galway City
# ...

# %%
#Sorting by one value
office = df.sort_values("PropertyAreaOffice")
office.head()
# Out:
#      PropertyID PropertyStreetCode PropertyTown PropertyCounty  \
# 5465     U12438   Gort na hAbhana        Ennis       Co. Clare
# 4207       3084        Silver Hill     Bundoran    Co. Donegal
# 4212       3085        Silver Hill     Bundoran    Co. Donegal
# 4260       3068        Silver Hill     Bundoran    Co. Donegal
# 4261       3072        Silver Hill     Bundoran    Co. Donegal
#
#      PropertyCurrentStatus PropertyType PropertyAreaOffice  \
# 5465              Occupied     Property        Aimee McGee
# 4207              Occupied     Property        Aimee McGee
# 4212              Occupied     Property        Aimee McGee
# 4260              Occupied     Property        Aimee McGee
# 4261              Occupied     Property        Aimee McGee
#
#              PropertyOwningBody PropertyLocalAuthorityArea PropertySubType  \
# 5465  Residential In Management              Clare County    General Needs
# 4207  Residential In Management            Donegal County    General Needs
# ...

# %%
#Sorting by multiple values
office [office["PropertyAreaOffice"] == "Aimee McGee"]
# Out:
#      PropertyID PropertyStreetCode PropertyTown PropertyCounty  \
# 5465     U12438   Gort na hAbhana        Ennis       Co. Clare
# 4207       3084        Silver Hill     Bundoran    Co. Donegal
# 4212       3085        Silver Hill     Bundoran    Co. Donegal
# 4260       3068        Silver Hill     Bundoran    Co. Donegal
# 4261       3072        Silver Hill     Bundoran    Co. Donegal
# ...         ...                ...          ...            ...
# 870        7492        Cluain Dara   Kingscourt      Co. Cavan
# 67       U13249     Gort Na Fuinse     Headford     Co. Galway
# 417      U11762  Gort an Ghabhann   Claregalway     Co. Galway
# 890      U10950     Sycamore Drive        Ennis      Co. Clare
# 398      U12237     Letteragh Road      Galway      Co. Galway
#
#      PropertyCurrentStatus PropertyType PropertyAreaOffice  \
# 5465              Occupied     Property        Aimee McGee
# 4207              Occupied     Property        Aimee McGee
# ...

# %%
#Sorting returning one column
df["PropertyTown"]
# Out:
# 0          Milltown
# 1          Milltown
# 2          Milltown
# 3          Milltown
# 4          Milltown
#             ...
# 10926       Galway
# 10927       Galway
# 10928    Clondalkin
# 10929    Clondalkin
# 10930       Galway
# Name: PropertyTown, Length: 10931, dtype: object

# %%
#Sorting - renaming columns
df.rename(columns ={"PropertyLocalAuthorityArea": "LocalAuthority", "PropertyAreaOffice": "HousingManager"}, inplace = True)
df.head()
# Out:
#   PropertyID PropertyStreetCode PropertyTown PropertyCounty  \
# 0     U13210      Ard Na Greine     Milltown      Co. Kerry
# 1     U13211      Ard Na Greine     Milltown      Co. Kerry
# 2     U13217      Ard Na Greine     Milltown      Co. Kerry
# 3     U13223      Ard Na Greine     Milltown      Co. Kerry
# 4     U13224      Ard Na Greine     Milltown      Co. Kerry
#
#   PropertyCurrentStatus PropertyType HousingManager  \
# 0              Occupied     Property  Gerard Deegan
# 1              Occupied     Property  Gerard Deegan
# 2              Occupied     Property  Gerard Deegan
# 3              Occupied     Property  Gerard Deegan
# 4              Occupied     Property  Gerard Deegan
#
#           PropertyOwningBody LocalAuthority PropertySubType  \
# 0  Residential In Management  Kerry County    General Needs
# 1  Residential In Management  Kerry County    General Needs
# 2  Residential In Management  Kerry County    General Needs
# ...

# %%
#Indexing - changing the index 
df = df.set_index(["PropertyID"])
df.head()
# Out:
#            PropertyStreetCode PropertyTown PropertyCounty  \
# PropertyID
# U13210          Ard Na Greine     Milltown      Co. Kerry
# U13211          Ard Na Greine     Milltown      Co. Kerry
# U13217          Ard Na Greine     Milltown      Co. Kerry
# U13223          Ard Na Greine     Milltown      Co. Kerry
# U13224          Ard Na Greine     Milltown      Co. Kerry
#
#            PropertyCurrentStatus PropertyType HousingManager  \
# PropertyID
# U13210                  Occupied     Property  Gerard Deegan
# U13211                  Occupied     Property  Gerard Deegan
# U13217                  Occupied     Property  Gerard Deegan
# U13223                  Occupied     Property  Gerard Deegan
# U13224                  Occupied     Property  Gerard Deegan
#
#                    PropertyOwningBody LocalAuthority PropertySubType  \
# PropertyID
# U13210      Residential In Management  Kerry County    General Needs
# ...

# %%
#Indexing - resetting the index 
df = df.reset_index()
df.head()
# Out:
#   PropertyID PropertyStreetCode PropertyTown PropertyCounty  \
# 0     U13210      Ard Na Greine     Milltown      Co. Kerry
# 1     U13211      Ard Na Greine     Milltown      Co. Kerry
# 2     U13217      Ard Na Greine     Milltown      Co. Kerry
# 3     U13223      Ard Na Greine     Milltown      Co. Kerry
# 4     U13224      Ard Na Greine     Milltown      Co. Kerry
#
#   PropertyCurrentStatus PropertyType HousingManager  \
# 0              Occupied     Property  Gerard Deegan
# 1              Occupied     Property  Gerard Deegan
# 2              Occupied     Property  Gerard Deegan
# 3              Occupied     Property  Gerard Deegan
# 4              Occupied     Property  Gerard Deegan
#
#           PropertyOwningBody LocalAuthority PropertySubType  \
# 0  Residential In Management  Kerry County    General Needs
# 1  Residential In Management  Kerry County    General Needs
# 2  Residential In Management  Kerry County    General Needs
# ...

# %%
#Indexing - using multiple indices
PropStyle = df.set_index(["PropertyStyle", "BedSpaces"])
PropStyle.head()
# Out:
#                               PropertyID PropertyStreetCode PropertyTown  \
# PropertyStyle       BedSpaces
# Semi-detached House 4             U13210      Ard Na Greine     Milltown
#                     4             U13211      Ard Na Greine     Milltown
#                     3             U13217      Ard Na Greine     Milltown
#                     3             U13223      Ard Na Greine     Milltown
#                     3             U13224      Ard Na Greine     Milltown
#
#                               PropertyCounty PropertyCurrentStatus  \
# PropertyStyle       BedSpaces
# Semi-detached House 4              Co. Kerry              Occupied
#                     4              Co. Kerry              Occupied
#                     3              Co. Kerry              Occupied
#                     3              Co. Kerry              Occupied
#                     3              Co. Kerry              Occupied
#
# ...

# %%
#Grouping - two columns and counting
df.groupby("PropertyCounty")["PropertyStyle"].count()
# Out:
# PropertyCounty
# Co. Carlow        205
# Co. Cavan         113
# Co. Clare          93
# Co. Cork         1422
# Co. Donegal       184
# Co. Dublin        834
# Co. Galway        698
# Co. Kerry         516
# Co. Kildare       690
# Co. Kilkenny      107
# Co. Laois         473
# Co. Leitrim        11
# Co. Limerick      298
# Co. Longford      142
# Co. Louth         664
# Co. Mayo          166
# Co. Meath         522
# Co. Monaghan       21
# Co. Offaly        126
# Co. Roscommon      39
# Co. Sligo         144
# Co. Tipperary     289
# Co. Waterford     231
# Co. Westmeath      57
# Co. Wexford       356
# Co. Wicklow        94
# DUblin 1            2
# DUblin 15           1
# Dublin 1          178
# Dublin 1           80
# Dublin 10           7
# Dublin 11         174
# Dublin 12          42
# Dublin 13         321
# Dublin 14          20
# Dublin 15         175
# Dublin 16           1
# Dublin 17          64
# Dublin 18         289
# Dublin 20          70
# ...

# %%
#Grouping - by multiple columns and counting
df.groupby(["HousingManager","PropertyCounty"])["PropertyID"].count()
# Out:
# HousingManager  PropertyCounty
# Aimee McGee     Co. Cavan          76
#                 Co. Clare          93
#                 Co. Donegal       167
#                 Co. Galway        543
#                 Co. Leitrim        11
#                                  ...
# Sold/Disposed   Co. Offaly          1
#                 Co. Wicklow        12
#                 Dublin 18          26
#                 Dublin 24           1
#                 Dublin 4            1
# Name: PropertyID, Length: 99, dtype: int64

# %%
#Grouping - by multiple columns and counting
df.groupby(["PropertyCounty","PropertyStyle","BedSpaces"])["PropertyID"].count()
# Out:
# PropertyCounty  PropertyStyle            BedSpaces
# Co. Carlow      Bungalow -detached       4             1
#                 Bungalow -semi-detached  1             1
#                                          2            11
#                                          3             7
#                 Detached House           3             1
#                                                       ..
# Dublin 8        Bungalow - terraced      2             1
#                 Duplex                   2            11
#                                          3             1
# Dublin 9        Apartment                1            13
#                                          2            28
# Name: PropertyID, Length: 505, dtype: int64

# %%
#Drop Duplicates - first make a copy of the dataframe and check results. 
df2 = property.copy()
df2.shape
# Out:
# (10931, 13)

# %%
#for demonstration purposes drop all duplicate Town Names
df2.drop_duplicates(subset = "PropertyTown", keep = "first", inplace = True)
df2.shape
# Out:
# (376, 13)

# %%
#Replace missing values - 7 columns have missing data
property.isna().sum()
# Out:
# PropertyID                 0
# PropertyStreetCode         0
# PropertyTown             239
# PropertyCounty           140
# PropertyCurrentStatus     60
# PropertyType             143
# HousingManager             0
# PropertyOwningBody         0
# LocalAuthority            61
# PropertySubType           25
# PropertyStyle             41
# YearOfConstruction         0
# BedSpaces                  0
# dtype: int64

# %%
#Replace missing values with fillna
property["PropertyTown"].fillna("To be updated", inplace = True)
property["PropertyCounty"].fillna("To be updated", inplace = True)
property["PropertyCurrentStatus"].fillna("To be updated", inplace = True)
property["PropertyType"].fillna("Type unknown", inplace = True)
property["LocalAuthority"].fillna("To be updated", inplace = True)
property["PropertySubType"].fillna("To be updated", inplace = True)
property["PropertyStyle"].fillna("To be updated", inplace = True)
property.isna().sum()
# Out:
# PropertyID               0
# PropertyStreetCode       0
# PropertyTown             0
# PropertyCounty           0
# PropertyCurrentStatus    0
# PropertyType             0
# HousingManager           0
# PropertyOwningBody       0
# LocalAuthority           0
# PropertySubType          0
# PropertyStyle            0
# YearOfConstruction       0
# BedSpaces                0
# dtype: int64

# %%
#Divide and merge DataFrames
P1 = property.copy()
P1.shape
# Out:
# (10931, 13)

# %%
#Split by coloumns using iloc
firsthalf = P1.iloc[:,:6]
secondhalf = P1.iloc[:,6:]
print(firsthalf)
print("**********************************************************************************************")
print(secondhalf)
# Out:
#       PropertyID PropertyStreetCode PropertyTown PropertyCounty  \
# 0         U13210      Ard Na Greine     Milltown      Co. Kerry
# 1         U13211      Ard Na Greine     Milltown      Co. Kerry
# 2         U13217      Ard Na Greine     Milltown      Co. Kerry
# 3         U13223      Ard Na Greine     Milltown      Co. Kerry
# 4         U13224      Ard Na Greine     Milltown      Co. Kerry
# ...          ...                ...          ...            ...
# 10926     U14165     Letteragh Road      Galway      Co. Galway
# 10927     U14166     Letteragh Road      Galway      Co. Galway
# 10928     U14130          San Guida   Clondalkin      Dublin 22
# 10929     U14135          San Guida   Clondalkin      Dublin 22
# 10930     U14163     Letteragh Road      Galway      Co. Galway
#
#       PropertyCurrentStatus PropertyType
# 0                  Occupied     Property
# 1                  Occupied     Property
# 2                  Occupied     Property
# ...

# %%
#Split by rows using iloc
first = P1.iloc[:5001,:]
second = P1.iloc[5001:,:]
print(first)
print("**********************************************************************************************")
print(second)
# Out:
#      PropertyID            PropertyStreetCode PropertyTown PropertyCounty  \
# 0        U13210                 Ard Na Greine     Milltown      Co. Kerry
# 1        U13211                 Ard Na Greine     Milltown      Co. Kerry
# 2        U13217                 Ard Na Greine     Milltown      Co. Kerry
# 3        U13223                 Ard Na Greine     Milltown      Co. Kerry
# 4        U13224                 Ard Na Greine     Milltown      Co. Kerry
# ...         ...                           ...          ...            ...
# 4996     U12838  An Tobar, Newfoundwell Road     Drogheda       Co. Louth
# 4997     U12841  An Tobar, Newfoundwell Road     Drogheda       Co. Louth
# 4998     U12844  An Tobar, Newfoundwell Road     Drogheda       Co. Louth
# 4999     U12846  An Tobar, Newfoundwell Road     Drogheda       Co. Louth
# 5000     U12848  An Tobar, Newfoundwell Road     Drogheda       Co. Louth
#
#      PropertyCurrentStatus PropertyType HousingManager  \
# ...

# %%
#Merge DataFrames adding code to prevent dupliate column names
merged = pd.merge(firsthalf,secondhalf, how = "outer", left_index = True, right_index = True, suffixes = ('','drop'))
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10931 entries, 0 to 10930
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   PropertyID             10931 non-null  object
#  1   PropertyStreetCode     10931 non-null  object
#  2   PropertyTown           10931 non-null  object
#  3   PropertyCounty         10931 non-null  object
#  4   PropertyCurrentStatus  10931 non-null  object
#  5   PropertyType           10931 non-null  object
#  6   HousingManager         10931 non-null  object
#  7   PropertyOwningBody     10931 non-null  object
#  8   LocalAuthority         10931 non-null  object
#  9   PropertySubType        10931 non-null  object
#  10  PropertyStyle          10931 non-null  object
#  11  YearOfConstruction     10931 non-null  int64
#  12  BedSpaces              10931 non-null  int64
# dtypes: int64(2), object(11)
# memory usage: 1.1+ MB

# %%
# using NumPy functions - using Titanic dataset as it has more numeric values than the property dataset
titanic = pd.read_csv(r'../data/Titanic.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
titanic.shape
# Out:
# (418, 12)

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
#Histogram with title 
titanic['Age'].hist(bins=10)
plt.title('Age Distribution of Passengers', loc = 'center', fontsize = 14)
# Out:
# Text(0.5, 1.0, 'Age Distribution of Passengers')

# %%
#Sex of passengers
df = titanic
df['Sex'].value_counts()
# Out:
# male      266
# female    152
# Name: Sex, dtype: int64

# %%
labels = ['Male','Female']
plt.xlabel('Sex')
plt.ylabel('Count')
plt.bar(labels, df['Sex'].value_counts(), color = 'orange')
plt.title('Sex of Passengers on Titanic')
# Out:
# Text(0.5, 1.0, 'Sex of Passengers on Titanic')

# %% [markdown]
# # 4. Analysis of Data
#
# Conditional statements, looping, groupby, using NumPy, dictionary or lists and defining a custom function to create reuseable code.

# %%
#Reusable code, looping, conditional statements

import enum


class Region(enum.Enum):
    C = 'Connacht'
    L = 'Leinster'
    M = "Munster"
    U = 'Ulster'


class County(enum.Enum):
    CL = 'Clare', Region.M
    C = 'Cork', Region.M
    KY = 'Kerry', Region.M
    LK = 'Limerick', Region.M
    T = 'Tipperary', Region.M
    W = 'Waterford', Region.M

    CW = 'Carlow', Region.L
    D = 'Dublin', Region.L
    KE = 'Kildare', Region.L
    KK = 'Kilkenny', Region.L
    LS = 'Laois', Region.L
    LD = 'Longford', Region.L
    LH = 'Louth', Region.L
    MH = 'Meath', Region.L
    OY = 'Offaly', Region.L
    WH = 'Westmeath', Region.L
    WW = 'Wicklow', Region.L
    WX = 'Wexford', Region.L

    G = 'Galway', Region.C
    LM = 'Leitrim', Region.C
    MO = 'Mayo', Region.C
    RN = 'Roscommon', Region.C
    SO = 'Sligo', Region.C

    CN = 'Cavan', Region.U
    MN = 'Monaghan', Region.U
    DL = 'Donegal', Region.U


df = pd.read_csv(r'../data/Property Dataset Final.csv')
d = df.to_dict('list')
d['Province'] = []

for pc in d['PropertyCounty']:
    try:
        is_match = [c for c in County if c.value[0] in pc]
        if is_match:
            province_name = is_match[0].value[1].value
            d['Province'].append(province_name)
        else:
            d['Province'].append('Invalid Data')
    except Exception as exc:
        d['Province'].append('Invalid Data')

new_df = pd.DataFrame.from_dict(d)
new_df.head(100)
# Out:
#    PropertyID       PropertyStreetCode               PropertyTown  \
# 0      U13210            Ard Na Greine                   Milltown
# 1      U13211            Ard Na Greine                   Milltown
# 2      U13217            Ard Na Greine                   Milltown
# 3      U13223            Ard Na Greine                   Milltown
# 4      U13224            Ard Na Greine                   Milltown
# ..        ...                      ...                        ...
# 95     U12868  Elmwood-Johnstown Place  Cabinteely, Dún Laoghaire
# 96     U12872  Elmwood-Johnstown Place  Cabinteely, Dún Laoghaire
# 97     U12873  Elmwood-Johnstown Place  Cabinteely, Dún Laoghaire
# 98     U12875  Elmwood-Johnstown Place  Cabinteely, Dún Laoghaire
# 99     U12876  Elmwood-Johnstown Place  Cabinteely, Dún Laoghaire
#
#    PropertyCounty PropertyCurrentStatus PropertyType PropertyAreaOffice  \
# 0       Co. Kerry              Occupied     Property      Gerard Deegan
# ...

# %%
#Dropping columns that wont be used and renaming columns
df3 = new_df.drop(['PropertyID','PropertyStreetCode','PropertyCurrentStatus','PropertyType','PropertyOwningBody','PropertySubType'], axis = 1)
df3.rename(columns ={'PropertyLocalAuthorityArea': 'LocalAuthority', 'PropertyAreaOffice':'HousingManager'}, inplace=True)
df3.tail()
# Out:
#       PropertyTown PropertyCounty HousingManager        LocalAuthority  \
# 10926      Galway      Co. Galway    Aimee McGee          Galway City
# 10927      Galway      Co. Galway    Aimee McGee          Galway City
# 10928   Clondalkin      Dublin 22    Brian Lambe  South Dublin County
# 10929   Clondalkin      Dublin 22    Brian Lambe  South Dublin County
# 10930      Galway      Co. Galway    Aimee McGee          Galway City
#
#       PropertyStyle  YearOfConstruction  BedSpaces  Province
# 10926     Apartment                2023          2  Connacht
# 10927     Apartment                2023          2  Connacht
# 10928     Apartment                2023          1  Leinster
# 10929     Apartment                2023          1  Leinster
# 10930     Apartment                2023          2  Connacht

# %%
#filling in blank data in rows
df3.isna().sum()
# Out:
# PropertyTown          239
# PropertyCounty        140
# HousingManager          0
# LocalAuthority         61
# PropertyStyle          41
# YearOfConstruction      0
# BedSpaces               0
# Province                0
# dtype: int64

# %%
#filling in blank data in rows
df3['PropertyTown'].fillna('To be updated', inplace = True)
df3['PropertyCounty'].fillna('To be updated', inplace = True)
df3['LocalAuthority'].fillna('To be updated', inplace = True)
df3['PropertyStyle'].fillna('To be updated', inplace = True)
df3.isna().sum()
# Out:
# PropertyTown          0
# PropertyCounty        0
# HousingManager        0
# LocalAuthority        0
# PropertyStyle         0
# YearOfConstruction    0
# BedSpaces             0
# Province              0
# dtype: int64

# %%
df3.info()
#checking how many columns are str
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10931 entries, 0 to 10930
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   PropertyTown        10931 non-null  object
#  1   PropertyCounty      10931 non-null  object
#  2   HousingManager      10931 non-null  object
#  3   LocalAuthority      10931 non-null  object
#  4   PropertyStyle       10931 non-null  object
#  5   YearOfConstruction  10931 non-null  int64
#  6   BedSpaces           10931 non-null  int64
#  7   Province            10931 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 683.3+ KB

# %%
#cleaning out white spaces from str data
df3['PropertyTown'] = df3['PropertyTown'].str.strip()
df3['PropertyCounty'] = df3['PropertyCounty'].str.strip()
df3['HousingManager'] = df3['HousingManager'].str.strip()
df3['LocalAuthority'] = df3['LocalAuthority'].str.strip()
df3['PropertyStyle'] = df3['PropertyStyle'].str.strip()
df3['Province'] = df3['Province'].str.strip()

# %% [markdown]
# # 5. Visualisation
#
# Generate two charts using Matplotlib or Seaborn.

# %%
#Using fig and ax and showing an empty plot
fig, ax = plt.subplots()
plt.show()

# %%
#displaying numbers as whole numbers
pd.options.display.float_format = "{:.0f}".format
h = df3.describe()
h
# Out:
#        YearOfConstruction  BedSpaces
# count               10931      10931
# mean                 2010          2
# std                    10          1
# min                  1930          0
# 25%                  2004          2
# 50%                  2008          2
# 75%                  2020          3
# max                  2023         16

# %%
h.plot(kind = 'hist', xlabel = 'Frequency')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df3.groupby('YearOfConstruction')['BedSpaces'].count().plot()
# Out:
# <Axes: xlabel='YearOfConstruction'>

# %%
df3.groupby('LocalAuthority')['PropertyStyle'].count().plot()
# Out:
# <Axes: xlabel='LocalAuthority'>

# %%
x = df3.hist(column=('YearOfConstruction'), bins=25, grid=False, figsize=(12,8), color = 'orange')

# %% [markdown]
# # 6. Insights
#
# Derive five valuable insights from the analysis and justify with reference to analysis or charts.

# %% [markdown]
# # 7. Machine Learning
#
# Describe what kind of prediction could be performed using classification or regression methods
