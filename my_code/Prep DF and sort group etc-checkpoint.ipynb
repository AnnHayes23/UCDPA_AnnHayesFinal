# %%
import pandas as pd
property = pd.read_excel(r'../data/Property Dataset Final.xlsx')
property.head()
# Out:
#   PropertyID PropertyTown PropertyCounty PropertyCurrentStatus PropertyType  \
# 0     U13210     Milltown      Co. Kerry              Occupied     Property
# 1     U13211     Milltown      Co. Kerry              Occupied     Property
# 2     U13217     Milltown      Co. Kerry              Occupied     Property
# 3     U13223     Milltown      Co. Kerry              Occupied     Property
# 4     U13224     Milltown      Co. Kerry              Occupied     Property
#
#   PropertyAreaOffice         PropertyOwningBody PropertyLocalAuthorityArea  \
# 0      Gerard Deegan  Residential In Management              Kerry County
# 1      Gerard Deegan  Residential In Management              Kerry County
# 2      Gerard Deegan  Residential In Management              Kerry County
# 3      Gerard Deegan  Residential In Management              Kerry County
# 4      Gerard Deegan  Residential In Management              Kerry County
#
# ...

# %%
property = pd.read_csv(r'../data/Property Dataset Final_150.csv')
property.head()
# Out:
#   PropertyID PropertyStreetCode PropertyTown PropertyCounty  \
# 0     U13210      Ard Na Greine     Milltown      Co. Kerry
# 1     U13211      Ard Na Greine     Milltown      Co. Kerry
# 2     U13217      Ard Na Greine     Milltown      Co. Kerry
# 3     U13223      Ard Na Greine     Milltown      Co. Kerry
# 4     U13224      Ard Na Greine     Milltown      Co. Kerry
#
#   PropertyCurrentStatus PropertyType PropertyAreaOffice  \
# 0              Occupied     Property      Gerard Deegan
# 1              Occupied     Property      Gerard Deegan
# 2              Occupied     Property      Gerard Deegan
# 3              Occupied     Property      Gerard Deegan
# 4              Occupied     Property      Gerard Deegan
#
#           PropertyOwningBody PropertyLocalAuthorityArea PropertySubType  \
# 0  Residential In Management              Kerry County    General Needs
# 1  Residential In Management              Kerry County    General Needs
# ...

# %%
property.shape
# Out:
# (11699, 20)

# %%
property.describe()
#not in any way useful for longitude, latitude but year of conscruction % and bed spaces might be useful
# Out:
#        PropertyLatitude  PropertyLongitude  YearOfConstruction     BedSpaces
# count      11699.000000       11699.000000        11699.000000  11699.000000
# mean          49.720839          -6.894054         1878.503633      2.269596
# std           12.937171           2.107564          497.341450      0.891522
# min            0.000000         -10.266660            0.000000      0.000000
# 25%           52.330032          -8.401104         2003.000000      2.000000
# 50%           53.269270          -6.803367         2008.000000      2.000000
# 75%           53.403565          -6.293380         2020.000000      3.000000
# max           55.176926           0.000000         2023.000000     16.000000

# %%
property.index
# Out:
# RangeIndex(start=0, stop=11699, step=1)

# %%
property.sort_values("PropertyAreaOffice")
# Out:
#       PropertyID                            PropertyName PropertyAreaCode  \
# 11698     U14163         61  Cnocan Glas, Letteragh Road      Aimee McGee
# 2896      U10068              169 Acha Bhile, Loughville      Aimee McGee
# 8444        3941                        56 Lios Na Circe      Aimee McGee
# 8445        3945                        49 Lios Na Circe      Aimee McGee
# 8446        3948                        57 Lios Na Circe      Aimee McGee
# ...          ...                                     ...              ...
# 1519        6143                        Entered in Error    Sold/Disposed
# 8433        3922                  DISPOSED: 6 Dunloe Ave    Sold/Disposed
# 8432        3921           DISPOSED: 5 Dunloe Drive Apt.    Sold/Disposed
# 1523        6148                  13 Saint Johns Terrace    Sold/Disposed
# 8516        4558  DISPOSED Room 3 Mulroy Park Group Home    Sold/Disposed
#
#                         PropertyStreetCode    PropertyNumber  \
# ...

# %%
property[property["PropertyAreaOffice"]=="Aimee McGee"]
# Out:
#       PropertyID                        PropertyName PropertyAreaCode  \
# 53        U13168                            Grallagh      Aimee McGee
# 60        U13149  38 Cedar Avenue, The Gallops, Latt      Aimee McGee
# 65        U13247                   41 Gort Na Fuinse      Aimee McGee
# 66        U13248                   42 Gort Na Fuinse      Aimee McGee
# 67        U13249                   43 Gort Na Fuinse      Aimee McGee
# ...          ...                                 ...              ...
# 11692     U14162     60  Cnocan Glas, Letteragh Road      Aimee McGee
# 11693     U14164     62  Cnocan Glas, Letteragh Road      Aimee McGee
# 11694     U14165     63  Cnocan Glas, Letteragh Road      Aimee McGee
# 11695     U14166     64  Cnocan Glas, Letteragh Road      Aimee McGee
# 11698     U14163     61  Cnocan Glas, Letteragh Road      Aimee McGee
#
#       PropertyStreetCode PropertyNumber                   PropertyStreet  \
# ...

# %%
import numpy as np
property.isnull().sum()
# Out:
# PropertyID                 0
# PropertyName               0
# PropertyAreaCode           0
# PropertyStreetCode         0
# PropertyNumber           162
# PropertyStreet           247
# PropertyTown             295
# PropertyCounty           267
# eircode                  275
# PropertyCurrentStatus     64
# PropertyType             175
# HousingManager             0
# PropertyOwningBody         1
# LocalAuthority           694
# PropertySubType          496
# PropertyStyle            171
# PropertyLatitude           0
# PropertyLongitude          0
# YearOfConstruction         0
# BedSpaces                  0
# dtype: int64

# %%
import pandas as pd
property = pd.read_excel(r'C:\Users\ahayes\PycharmProjects\UCDPA_AH_PROPER\data\Property Dataset March 2023.xlsx')
property.groupby('PropertyCounty')['PropertyStyle'].count()
#some duplication of county names and merging of other is needed to tidy up this data
# Out:
# PropertyCounty
# Co. Carlow        235
# Co. Cavan         114
# Co. Clare          95
# Co. Cork         1443
# Co. Donegal       208
# Co. Dublin        862
# Co. Galway        722
# Co. Kerry         536
# Co. Kildare       721
# Co. Kilkenny      109
# Co. Laois         482
# Co. Leitrim        11
# Co. Limerick      338
# Co. Longford      164
# Co. Louth         666
# Co. Mayo          203
# Co. Meath         535
# Co. Monaghan       21
# Co. Offaly        131
# Co. Roscommon      40
# Co. Sligo         155
# Co. Tipperary     294
# Co. Waterford     252
# Co. Westmeath      57
# Co. Wexford       358
# Co. Wicklow       119
# Cork                7
# DUblin 1            2
# DUblin 15           1
# Dublin              1
# Dublin 1          183
# Dublin 1           80
# Dublin 10           9
# Dublin 11         176
# Dublin 12          44
# Dublin 13         322
# Dublin 14          20
# Dublin 15         175
# Dublin 16           2
# Dublin 17          64
# ...

# %%
#changing index on the data
New = pd.read_excel(r'C:\Users\ahayes\PycharmProjects\UCDPA_AH_PROPER\data\Property Dataset March 2023.xlsx')
New = pd.read_excel(r'C:\Users\ahayes\PycharmProjects\UCDPA_AH_PROPER\data\Property Dataset March 2023.xlsx', index_col = "PropertyID")
New.head()
# Out:
#                                        PropertyName PropertyAreaCode  \
# PropertyID
# U13210       7 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# U13211       8 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# U13217      14 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# U13223      20 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# U13224      21 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
#
#            PropertyStreetCode PropertyNumber  \
# PropertyID
# U13210          Ard Na Greine              7
# U13211          Ard Na Greine              8
# U13217          Ard Na Greine             14
# U13223          Ard Na Greine             20
# U13224          Ard Na Greine             21
#
#                                   PropertyStreet PropertyTown PropertyCounty  \
# PropertyID
# U13210      Oak Drive, Ard Na Greine, Knockavota     Milltown      Co. Kerry
# U13211      Oak Drive, Ard Na Greine, Knockavota     Milltown      Co. Kerry
# ...

# %%
#returning just one column
New ["PropertyTown"]
New.PropertyTown
# Out:
# PropertyID
# U13210      Milltown
# U13211      Milltown
# U13217      Milltown
# U13223      Milltown
# U13224      Milltown
#              ...
# U14165       Galway
# U14166       Galway
# U14130    Clondalkin
# U14135    Clondalkin
# U14163       Galway
# Name: PropertyTown, Length: 11699, dtype: object

# %%
#deleting columns - Longitude and Latitude
New = pd.read_excel(r'C:\Users\ahayes\PycharmProjects\UCDPA_AH_PROPER\data\Property Dataset March 2023.xlsx', index_col = "PropertyID")
New.drop("PropertyLatitude",inplace = True, axis = 1)
New.head()
New.drop("PropertyLongitude",inplace = True, axis = 1)
New.head()
# Out:
#                                        PropertyName PropertyAreaCode  \
# PropertyID
# U13210       7 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# U13211       8 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# U13217      14 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# U13223      20 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# U13224      21 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
#
#            PropertyStreetCode PropertyNumber  \
# PropertyID
# U13210          Ard Na Greine              7
# U13211          Ard Na Greine              8
# U13217          Ard Na Greine             14
# U13223          Ard Na Greine             20
# U13224          Ard Na Greine             21
#
#                                   PropertyStreet PropertyTown PropertyCounty  \
# PropertyID
# U13210      Oak Drive, Ard Na Greine, Knockavota     Milltown      Co. Kerry
# U13211      Oak Drive, Ard Na Greine, Knockavota     Milltown      Co. Kerry
# ...

# %%
#add additional column
New ["Province"] =""
New.head()
# Out:
#                                        PropertyName PropertyAreaCode  \
# PropertyID
# U13210       7 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# U13211       8 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# U13217      14 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# U13223      20 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# U13224      21 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
#
#            PropertyStreetCode PropertyNumber  \
# PropertyID
# U13210          Ard Na Greine              7
# U13211          Ard Na Greine              8
# U13217          Ard Na Greine             14
# U13223          Ard Na Greine             20
# U13224          Ard Na Greine             21
#
#                                   PropertyStreet PropertyTown PropertyCounty  \
# PropertyID
# U13210      Oak Drive, Ard Na Greine, Knockavota     Milltown      Co. Kerry
# U13211      Oak Drive, Ard Na Greine, Knockavota     Milltown      Co. Kerry
# ...

# %%
New[New["PropertyCounty"]=="Co.Kerry"]
New.head()
# Out:
#                                        PropertyName PropertyAreaCode  \
# PropertyID
# U13210       7 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# U13211       8 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# U13217      14 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# U13223      20 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# U13224      21 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
#
#            PropertyStreetCode PropertyNumber  \
# PropertyID
# U13210          Ard Na Greine              7
# U13211          Ard Na Greine              8
# U13217          Ard Na Greine             14
# U13223          Ard Na Greine             20
# U13224          Ard Na Greine             21
#
#                                   PropertyStreet PropertyTown PropertyCounty  \
# PropertyID
# U13210      Oak Drive, Ard Na Greine, Knockavota     Milltown      Co. Kerry
# U13211      Oak Drive, Ard Na Greine, Knockavota     Milltown      Co. Kerry
# ...

# %%
#Importing Data from Kaggle
Titanic = pd.read_csv(r'C:\Users\ahayes\PycharmProjects\UCDPA_AH_PROPER\data\Titanic.csv')
Titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#importing dataset from seaborn
#first check what is available on seaborn -http://seaborn.pydata.org/tutorial/introduction.html#multivariate-views-on-complex-datasets
import seaborn as sns
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#using an API
import requests

url = "https://unogsng.p.rapidapi.com/genres"

headers = {
        "X-RapidAPI-Key": "SIGN-UP-FOR-KEY",
        "X-RapidAPI-Host": "unogsng.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {"message":"You are not subscribed to this API."}

# %%
#subscribed to rapidapi.com and got a token and tried again
import requests

url = "https://unogsng.p.rapidapi.com/genres"

headers = {
	"X-RapidAPI-Key": "2f8253dc65mshf5db400c3152ac6p14007djsn78987098a841",
	"X-RapidAPI-Host": "unogsng.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {
#     "12739": "20th Century Period Pieces",
#     "77213": "Absurd Comedies",
#     "51063": "Academy Award-Winning Films",
#     "1365": "Acci\u00f3n y aventuras",
#     "2125": "Acci\u00f3n y aventuras militares",
#     "801362": "Action",
#     "10673": "Action & Adventure Programmes",
#     "2653": "Action Anime",
#     "43040": "Action Comedies",
#     "1568": "Action Sci-Fi & Fantasy",
#     "43048": "Action Thrillers",
#     "788212": "Actionkrimis",
#     "11881": "Adult Animation",
#     "7442": "Adventures",
#     "3761": "African Films",
#     "4906": "African-American Comedies",
#     "10778": "African-American Stand-up Comedy",
#     "3327": "Alien Sci-Fi",
#     "12123": "Ambientadas en otra \u00e9poca",
#     "72404": "American Programmes",
#     "5507": "Animal Tales",
#     "786708": "Animated Movies",
#     "4698": "Animation",
#     "7424": "Anime",
#     "1819777": "Anime based on a Video Game",
#     "1819776": "Anime based on Books",
# ...

# %%
# looks like a csv file but not too sure
genres = response.text
type(genres)
# Out:
# str

# %%
import json as json
myfile = json.loads(response.text)
movie_genres = pd.DataFrame(myfile.items(), columns = ["ID", "Genre"])
print(movie_genres)
movie_genres.head()
# Out:
#           ID                         Genre
# 0      12739    20th Century Period Pieces
# 1      77213               Absurd Comedies
# 2      51063   Academy Award-Winning Films
# 3       1365            Acción y aventuras
# 4       2125  Acción y aventuras militares
# ..       ...                           ...
# 659     7700                      Westerns
# 660     2856                   World Music
# 661    70023                    WWII Films
# 662  1502288                   Youth Drama
# 663    75405           Zombie Horror Films
#
# [664 rows x 2 columns]
#       ID                         Genre
# 0  12739    20th Century Period Pieces
# 1  77213               Absurd Comedies
# 2  51063   Academy Award-Winning Films
# 3   1365            Acción y aventuras
# 4   2125  Acción y aventuras militares

# %%
movie_genres.set_index("ID")
# Out:
#                                 Genre
# ID
# 12739      20th Century Period Pieces
# 77213                 Absurd Comedies
# 51063     Academy Award-Winning Films
# 1365               Acción y aventuras
# 2125     Acción y aventuras militares
# ...                               ...
# 7700                         Westerns
# 2856                      World Music
# 70023                      WWII Films
# 1502288                   Youth Drama
# 75405             Zombie Horror Films
#
# [664 rows x 1 columns]

# %%
#Preparation of data for my assignment
#Create a DataFrame
property = pd.read_excel(r'C:\Users\ahayes\PycharmProjects\UCDPA_AH_PROPER\data\Property Dataset March 2023.xlsx')
property.head()
# Out:
#   PropertyID                             PropertyName PropertyAreaCode  \
# 0     U13210   7 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# 1     U13211   8 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# 2     U13217  14 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# 3     U13223  20 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# 4     U13224  21 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
#
#   PropertyStreetCode PropertyNumber                        PropertyStreet  \
# 0      Ard Na Greine              7  Oak Drive, Ard Na Greine, Knockavota
# 1      Ard Na Greine              8  Oak Drive, Ard Na Greine, Knockavota
# 2      Ard Na Greine             14  Oak Drive, Ard Na Greine, Knockavota
# 3      Ard Na Greine             20  Oak Drive, Ard Na Greine, Knockavota
# 4      Ard Na Greine             21  Oak Drive, Ard Na Greine, Knockavota
#
#   PropertyTown PropertyCounty PropertyPostcode PropertyCurrentStatus  \
# ...

# %%
#Sorting data - first get a list of all column names, then sort by PropertyAreaOffice
property.columns
property.sort_values("PropertyAreaOffice")
# Out:
#       PropertyID                            PropertyName PropertyAreaCode  \
# 11698     U14163         61  Cnocan Glas, Letteragh Road      Aimee McGee
# 2896      U10068              169 Acha Bhile, Loughville      Aimee McGee
# 8444        3941                        56 Lios Na Circe      Aimee McGee
# 8445        3945                        49 Lios Na Circe      Aimee McGee
# 8446        3948                        57 Lios Na Circe      Aimee McGee
# ...          ...                                     ...              ...
# 1519        6143                        Entered in Error    Sold/Disposed
# 8433        3922                  DISPOSED: 6 Dunloe Ave    Sold/Disposed
# 8432        3921           DISPOSED: 5 Dunloe Drive Apt.    Sold/Disposed
# 1523        6148                  13 Saint Johns Terrace    Sold/Disposed
# 8516        4558  DISPOSED Room 3 Mulroy Park Group Home    Sold/Disposed
#
#                         PropertyStreetCode    PropertyNumber  \
# ...

# %%
#Sorting data - only look at the data for Sarah Mallon
property[property["PropertyAreaOffice"]=="Sarah Mallon"]
# Out:
#       PropertyID                        PropertyName PropertyAreaCode  \
# 15        U13330            1 Oak Court, The Willows     Sarah Mallon
# 16        U13331            2 Oak Court, The Willows     Sarah Mallon
# 17        U13332            3 Oak Court, The Willows     Sarah Mallon
# 18        U13333            4 Oak Court, The Willows     Sarah Mallon
# 19        U13334            5 Oak Court, The Willows     Sarah Mallon
# ...          ...                                 ...              ...
# 11641     U14127   47 The Drive, Saint Marnock's Bay     Sarah Mallon
# 11643     U14128   48 The Drive, Saint Marnock's Bay     Sarah Mallon
# 11644     U14129   49 The Drive, Saint Marnock's Bay     Sarah Mallon
# 11645     U14116  65 The Avenue, Saint Marnock's Bay     Sarah Mallon
# 11646     U14119  68 The Avenue, Saint Marnock's Bay     Sarah Mallon
#
#       PropertyStreetCode PropertyNumber                   PropertyStreet  \
# ...

# %%
#Sorting - returning just one column
New ["PropertyCounty"]
New.PropertyCounty
# Out:
# PropertyID
# U13210     Co. Kerry
# U13211     Co. Kerry
# U13217     Co. Kerry
# U13223     Co. Kerry
# U13224     Co. Kerry
#              ...
# U14165    Co. Galway
# U14166    Co. Galway
# U14130     Dublin 22
# U14135     Dublin 22
# U14163    Co. Galway
# Name: PropertyCounty, Length: 11699, dtype: object

# %%
#Sorting data - renaming columns to useful names
import pandas as pd
property = pd.read_excel(r'C:\Users\ahayes\PycharmProjects\UCDPA_AH_PROPER\data\Property Dataset March 2023.xlsx')
property.rename(columns ={"PropertyLocalAuthorityArea":"LocalAuthority","PropertyPostcode":"eircode","PropertyAreaOffice":"HousingManager"},inplace = True) 
property.head()
# Out:
#   PropertyID                             PropertyName PropertyAreaCode  \
# 0     U13210   7 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# 1     U13211   8 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# 2     U13217  14 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# 3     U13223  20 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# 4     U13224  21 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
#
#   PropertyStreetCode PropertyNumber                        PropertyStreet  \
# 0      Ard Na Greine              7  Oak Drive, Ard Na Greine, Knockavota
# 1      Ard Na Greine              8  Oak Drive, Ard Na Greine, Knockavota
# 2      Ard Na Greine             14  Oak Drive, Ard Na Greine, Knockavota
# 3      Ard Na Greine             20  Oak Drive, Ard Na Greine, Knockavota
# 4      Ard Na Greine             21  Oak Drive, Ard Na Greine, Knockavota
#
#   PropertyTown PropertyCounty   eircode PropertyCurrentStatus PropertyType  \
# ...

# %%
#Indexing - changing index on the data
New = pd.read_excel(r'C:\Users\ahayes\PycharmProjects\UCDPA_AH_PROPER\data\Property Dataset March 2023.xlsx')
New = pd.read_excel(r'C:\Users\ahayes\PycharmProjects\UCDPA_AH_PROPER\data\Property Dataset March 2023.xlsx', index_col = "PropertyID")
New.head()
# Out:
#                                        PropertyName PropertyAreaCode  \
# PropertyID
# U13210       7 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# U13211       8 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# U13217      14 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# U13223      20 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# U13224      21 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
#
#            PropertyStreetCode PropertyNumber  \
# PropertyID
# U13210          Ard Na Greine              7
# U13211          Ard Na Greine              8
# U13217          Ard Na Greine             14
# U13223          Ard Na Greine             20
# U13224          Ard Na Greine             21
#
#                                   PropertyStreet PropertyTown PropertyCounty  \
# PropertyID
# U13210      Oak Drive, Ard Na Greine, Knockavota     Milltown      Co. Kerry
# U13211      Oak Drive, Ard Na Greine, Knockavota     Milltown      Co. Kerry
# ...

# %%
#Indexing - resetting the index on the data
Old = New.reset_index()
Old.head()
# Out:
#   PropertyID                             PropertyName PropertyAreaCode  \
# 0     U13210   7 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# 1     U13211   8 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# 2     U13217  14 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# 3     U13223  20 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
# 4     U13224  21 Oak Drive, Ard Na Greine, Knockavota    Gerard Deegan
#
#   PropertyStreetCode PropertyNumber                        PropertyStreet  \
# 0      Ard Na Greine              7  Oak Drive, Ard Na Greine, Knockavota
# 1      Ard Na Greine              8  Oak Drive, Ard Na Greine, Knockavota
# 2      Ard Na Greine             14  Oak Drive, Ard Na Greine, Knockavota
# 3      Ard Na Greine             20  Oak Drive, Ard Na Greine, Knockavota
# 4      Ard Na Greine             21  Oak Drive, Ard Na Greine, Knockavota
#
#   PropertyTown PropertyCounty PropertyPostcode PropertyCurrentStatus  \
# ...

# %%
#Grouping
property.groupby(["PropertyCounty","PropertyStyle"])["PropertyStyle"].count()
# Out:
# PropertyCounty  PropertyStyle
# Co. Carlow      Bungalow                    21
#                 Bungalow -detached           1
#                 Bungalow -semi-detached     23
#                 Detached House               1
#                 Semi-detached House        108
#                                           ...
# Dublin 9        Apartment                   41
#                 Bungalow                     3
# Galway          Bungalow                     1
# Limerick        Bungalow                     1
# Waterford       Bungalow                     2
# Name: PropertyStyle, Length: 297, dtype: int64

# %%
#Grouping by multiple columns
property.groupby(["HousingManager","PropertyCounty"])["PropertyID"].count()
# Out:
# HousingManager  PropertyCounty
# Aimee McGee     Co. Cavan          76
#                 Co. Clare          93
#                 Co. Donegal       170
#                 Co. Galway        548
#                 Co. Leitrim        11
#                                  ...
# Sold/Disposed   Dublin 8           48
#                 Dublin 9            3
#                 Galway              1
#                 Limerick            1
#                 Waterford           2
# Name: PropertyID, Length: 131, dtype: int64

# %%
#Grouping by multiple columns
property.groupby(["PropertyCounty","PropertyStyle","BedSpaces"])["PropertyStyle"].count()
# Out:
# PropertyCounty  PropertyStyle            BedSpaces
# Co. Carlow      Bungalow                 1            8
#                                          2            6
#                                          3            7
#                 Bungalow -detached       4            1
#                 Bungalow -semi-detached  1            1
#                                                      ..
# Dublin 9        Bungalow                 3            2
# Galway          Bungalow                 3            1
# Limerick        Bungalow                 3            1
# Waterford       Bungalow                 2            1
#                                          3            1
# Name: PropertyStyle, Length: 596, dtype: int64

# %%
#return the number of columns and missing data
property.info()
#not what I had in mind - would like to see where the missing data is
property.isna().info()
#same result 
property.isna().sum()
#now I can see which column has missing data either blank or with null value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11699 entries, 0 to 11698
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PropertyID                  11699 non-null  object
#  1   PropertyName                11699 non-null  object
#  2   PropertyAreaCode            11699 non-null  object
#  3   PropertyStreetCode          11699 non-null  object
#  4   PropertyNumber              11537 non-null  object
#  5   PropertyStreet              11452 non-null  object
#  6   PropertyTown                11404 non-null  object
#  7   PropertyCounty              11432 non-null  object
#  8   PropertyPostcode            11424 non-null  object
#  9   PropertyCurrentStatus       11635 non-null  object
#  10  PropertyType                11524 non-null  object
#  11  PropertyAreaOffice          11699 non-null  object
#  12  PropertyOwningBody          11698 non-null  object
# ...

# %%
#Drop duplicates
property.drop_duplicates(subset="PropertyStreetCode", keep = "first", inplace = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-117-fce603c713a4> in <module>
#       1 #Drop duplicates
# ----> 2 property.drop_duplicates(subset="PropertyStreetCode", keep = "first", inplace = False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop_duplicates(self, subset, keep, inplace, ignore_index)
#    5269         inplace = validate_bool_kwarg(inplace, "inplace")
#    5270         ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# -> 5271         duplicated = self.duplicated(subset, keep=keep)
#    5272
#    5273         result = self[-duplicated]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in duplicated(self, subset, keep)
#    5403         diff = Index(subset).difference(self.columns)
#    5404         if not diff.empty:
# -> 5405             raise KeyError(diff)
#    5406
# ...

# %%
Local_Authority_group = property.groupby("PropertyLocalAuthorityArea")
LA_group = Local_Authority_group.get_group("NULL")
print(LA_group)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-113-cec07302a547> in <module>
# ----> 1 Local_Authority_group = property.groupby("PropertyLocalAuthorityArea")
#       2 LA_group = Local_Authority_group.get_group("NULL")
#       3 print(LA_group)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# ...
